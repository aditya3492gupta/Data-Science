# %% [raw]
# Data Visualisation Library
#
# Matplolib
# Ggplot
#
# Seaborn

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.linspace(0,10)
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x),color='black')

# %%
plt.plot(x,np.sin(x),linestyle='solid')

# %%
plt.plot(x,np.sin(x),linestyle='dashed')

# %%
plt.plot(x,np.sin(x),linestyle='dashdot')

# %%
plt.plot(x,np.sin(x),linestyle='dotted')

# %%
plt.plot(x,np.sin(x),linestyle='none')

# %% [raw]
# Linestyles
# 1.dotted
# 2.dashed
# 3.dashdot
# 4.none
# 5.solid
# 6.''

# %%
plt.plot(x,np.cos(x),'yo')
plt.show()

# %%
plt.plot(x,np.cos(x),'ys')
plt.show()

# %%
plt.plot(x,np.cos(x),'yd')
plt.show()

# %%
plt.plot(x,np.cos(x),'y1')
plt.show()

# %%
plt.plot(x,np.cos(x),'y*')
plt.show()

# %%
plt.plot(x,np.cos(x),'y_')
plt.show()

# %%
plt.plot(x,np.cos(x),'yo',color='black')
plt.show()
# Out:
# C:\Users\ADITYA GUPTA\AppData\Local\Temp\ipykernel_3368\810386006.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "yo" (-> color='y'). The keyword argument will take precedence.
#   plt.plot(x,np.cos(x),'yo',color='black')

# %%
guests=[19,22,20,26]
subscribers=[105,103,98,83]
plt.plot([guests,subscribers])
# Out:
# [<matplotlib.lines.Line2D at 0x1aca52af0a0>,
#  <matplotlib.lines.Line2D at 0x1aca52af100>,
#  <matplotlib.lines.Line2D at 0x1aca52af220>,
#  <matplotlib.lines.Line2D at 0x1aca52af340>]

# %%
langs=['C', 'C++' ,'Java ','Python' , 'PHP']
students=[23,17,35,29,12]
plt.bar(langs, students, width=0.75, color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
langs=['C', 'C++' ,'Java ','Python' , 'PHP']
students=[23,17,35,29,12]
plt.barh(langs, students,  color='black')
plt.show()
